# %%
import os
import glob
import pandas as pd
import psycopg2 as pg2
from sql_queries import *

# %%
conn = pg2.connect(database = 'governmentpayroll', user = 'postgres', password = 'poop1234' )
cur = conn.cursor()

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root, '*.csv'))
        for f in files:
            all_files.append(os.path.abspath(f))
    return all_files

# %%
files = get_files('payroll')
files[0]
# Out:
# 'C:\\Users\\alber\\Desktop\\myWork\\projects\\ETL\\payroll\\Payroll_Report_-_End_Date_1_23_2019.csv'

# %%
jan23 = pd.read_csv(files[0], dtype = object)
jan23.head()
# Out:
#          EMPLOYEE_NAME                         OFFICE      CITY  \
# 0      ABBOT, JUDITH L      SENATOR TOBY ANN STAVISKY  FLUSHING
# 1    ABRAHAM, PRINCY A       MINORITY COUNSEL/PROGRAM    ALBANY
# 2       ABREU, BRIAN A  LEGISLATIVE MESSENGER SERVICE    ALBANY
# 3  ACEVEDO, SAMANTHA I          SENATOR JESSICA RAMOS    ALBANY
# 4       ADAMS, DAVID V        SENATE SERGEANT-AT-ARMS    ALBANY
#
#              EMPLOYEE_TITLE BIWEEKLY/HOURLY_RATE PAYROLL_TYPE PAY_PERIOD  \
# 0         COMMUNITY LIAISON              1076.93           SA         21
# 1         ASSOCIATE COUNSEL              2376.93           RA         21
# 2                 MESSENGER              1173.93           RA         21
# 3        COMMITTEE DIRECTOR              2115.39           RA         21
# 4  SESSION SERGEANT-AT-ARMS               820.95           SA         21
#
#     PAY_PERIOD_BEGIN_DATE     PAY_PERIOD_END_DATE              CHECK_DATE  \
# ...

# %%
jan23['PAY_PERIOD_END_DATE'] = pd.to_datetime(jan23['PAY_PERIOD_END_DATE']).astype(object)
jan23['YEAR'] = jan23['PAY_PERIOD_END_DATE'].dt.year.astype(object)
payperiod_data = jan23.loc[0,['PAY_PERIOD', 'YEAR','PAY_PERIOD_BEGIN_DATE', 'PAY_PERIOD_END_DATE', 'CHECK_DATE']]
payperiod_data
# Out:
# PAY_PERIOD                                   21
# YEAR                                       2019
# PAY_PERIOD_BEGIN_DATE    01/10/2019 12:00:00 AM
# PAY_PERIOD_END_DATE         2019-01-23 00:00:00
# CHECK_DATE               02/06/2019 12:00:00 AM
# Name: 0, dtype: object

# %%
cur.execute(pay_period_table_insert, payperiod_data)
conn.commit()

# %%
payroll_type_data = jan23[['PAYROLL_TYPE']].drop_duplicates()
payroll_type_data.head()
# Out:
#    PAYROLL_TYPE
# 0            SA
# 1            RA
# 51           TE

# %%
for i, row in payroll_type_data.iterrows():
    cur.execute(payroll_type_table_insert, row)
    conn.commit()

# %%
city_data = jan23[['CITY']].drop_duplicates()
city_data.head()
# Out:
#        CITY
# 0  FLUSHING
# 1    ALBANY
# 5     BRONX
# 6     UTICA
# 7  NEW YORK

# %%
for i, row in city_data.iterrows():
    cur.execute(city_table_insert, row)
    conn.commit()

# %%
legislative_entity_data = jan23[['LEGISLATIVE_ENTITY']].drop_duplicates()
legislative_entity_data
# Out:
#            LEGISLATIVE_ENTITY
# 0             SENATE EMPLOYEE
# 2  JOINT LEGISLATIVE EMPLOYEE

# %%
for i, row in legislative_entity_data.iterrows():
    cur.execute(legislative_entity_insert, row)
    conn.commit()

# %%
employee_data = jan23[['EMPLOYEE_NAME', 'EMPLOYEE_TITLE', 'LEGISLATIVE_ENTITY']].drop_duplicates()
employee_data.head(20)
# Out:
#                EMPLOYEE_NAME                        EMPLOYEE_TITLE  \
# 0            ABBOT, JUDITH L                     COMMUNITY LIAISON
# 1          ABRAHAM, PRINCY A                     ASSOCIATE COUNSEL
# 2             ABREU, BRIAN A                             MESSENGER
# 3        ACEVEDO, SAMANTHA I                    COMMITTEE DIRECTOR
# 4             ADAMS, DAVID V              SESSION SERGEANT-AT-ARMS
# 5               ADDOH, ISAAC                     COMMUNITY LIAISON
# 6              ADEY, BRIAN T  DIRECTOR OF OPERATIONS AND ADMINISTR
# 7             ADLER, ROGER B                               COUNSEL
# 8         ADORNO, JONATHAN M      COMMUNITY AFFAIRS REPRESENTATIVE
# 9          AGALO-OS, GRACE P              ADMINISTRATIVE ASSISTANT
# 10         AGOSTO, KENNETH G                 DEPUTY CHIEF OF STAFF
# 11            AGUAM, RAYAN S                  NEW MEDIA SPECIALIST
# 12              AGUI, MARI S  EXECUTIVE ASSISTANT/EVENT COORDINATO
# ...

# %%
for i, row in employee_data.iterrows():
    cur.execute(employee_table_insert, row)
    conn.commit()
# Out:
# ---------------------------------------------------------------------------
# InvalidTextRepresentation                 Traceback (most recent call last)
# <ipython-input-8-3b39d88c1d78> in <module>
#       1 for i, row in employee_data.iterrows():
# ----> 2     cur.execute(employee_table_insert, row)
#       3     conn.commit()
#
# InvalidTextRepresentation: invalid input syntax for integer: "SENATE EMPLOYEE"
# LINE 3: ...  VALUES ('ABBOT, JUDITH L', 'COMMUNITY LIAISON', 'SENATE EM...
#                                                              ^

# %%
def isOneToOne(df, col1, col2):
    first = df.drop_duplicates([col1, col2]).groupby(col1)[col2].count().max()
    second = df.drop_duplicates([col1, col2]).groupby(col2)[col1].count().max()
    return first + second == 2

isOneToOne(jan_mod, 'LEGISLATIVE_ENTITY', 'EMPLOYEE_NAME')

first = jan23.groupby('PAY_PERIOD')['PAY_PERIOD_END_DATE'].count().max()
second = jan23.groupby('PAY_PERIOD_END_DATE')['PAY_PERIOD'].count().max()
print(first, second)
